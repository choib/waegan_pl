# %%
epoch=711
# !python waegan_resnet.py --date '0703mteg5attnostyle' --dataset_name "mteg_dataset_5" --no_noise --attention --style_ratio 0.05 --n_resblk 4 --cpt_interval 10 --batch_size 3 --validate --val_target "update" --epoch $epoch
# Out:
# ----------------- Options ---------------
#                       DDP: False
#                 add_graph: False
#                 attention: True                          	[default: False]
#                batch_size: 3                             	[default: 4]
#                clip_value: 0.01
#               clip_weight: True
#              cpt_interval: 10
#                   dataset: mteg_dataset_5                	[default: mteg_dataset_1]
#                      date: 0703mteg5attnostyle           	[default: 0425mteg1att]
#                descending: False
#              disc_channel: 1
#               disc_kernel: 3
#              disc_retrain: False
#                   dropout: 0.0
#                  enc_port: 6
#                     epoch: 711                           	[default: 0]
#                    epochs: 501
#                 ex_critic: True
#                       gan: True
#                 gp_lambda: 10
#                img_height: 256
# ...

# %%
epoch=711
# !python waegan_resnet.py --date '0703mteg5attnostyle' --dataset_name "mteg_dataset_5" --no_noise --attention --style_ratio 0.05 --n_resblk 4 --cpt_interval 10 --batch_size 3 --validate --val_target "update" --epoch $epoch
# Out:
# ----------------- Options ---------------
#                       DDP: False
#                 add_graph: False
#                 attention: True                          	[default: False]
#                batch_size: 3                             	[default: 4]
#                clip_value: 0.01
#               clip_weight: True
#              cpt_interval: 10
#                   dataset: mteg_dataset_5                	[default: mteg_dataset_1]
#                      date: 0703mteg5attnostyle           	[default: 0425mteg1att]
#                  deepdown: True
#                descending: False
#              disc_channel: 1
#               disc_kernel: 3
#              disc_retrain: False
#                   dropout: 0.0
#                  enc_loss: False
#                  enc_port: 6
#                     epoch: 871                           	[default: 0]
#                    epochs: 501
#                 ex_critic: True
#                full_style: False
# ...

# %%
epoch=871
# !python waegan_resnet.py --date '0703mteg5attnostyle' --dataset_name "mteg_dataset_5" --no_relu --no_style --no_noise --attention --style_ratio 0.05 --n_resblk 4 --cpt_interval 10 --batch_size 3 --validate --val_target "user" --epoch $epoch
# Out:
# ----------------- Options ---------------
#                       DDP: False
#                 add_graph: False
#                 attention: True                          	[default: False]
#                batch_size: 3                             	[default: 4]
#                clip_value: 0.01
#               clip_weight: True
#              cpt_interval: 10
#                   dataset: mteg_dataset_5                	[default: mteg_dataset_1]
#                      date: 0703mteg5attnostyle           	[default: 0425mteg1att]
#                  deepdown: True
#                descending: False
#              disc_channel: 1
#               disc_kernel: 3
#              disc_retrain: False
#                   dropout: 0.0
#                  enc_loss: False
#                  enc_port: 6
#                     epoch: 871                           	[default: 0]
#                    epochs: 501
#                 ex_critic: True
#                full_style: False
# ...

# %%
epoch=871
# !python waegan_resnet.py --date '0703mteg5attnostyle' --dataset_name "mteg_dataset_5" --no_relu --no_style --no_noise --attention --style_ratio 0.05 --n_resblk 4 --cpt_interval 10 --batch_size 3 --validate --val_target "train" --epoch $epoch
# Out:
# ----------------- Options ---------------
#                       DDP: False
#                 add_graph: False
#                 attention: True                          	[default: False]
#                batch_size: 3                             	[default: 4]
#                clip_value: 0.01
#               clip_weight: True
#              cpt_interval: 10
#                   dataset: mteg_dataset_5                	[default: mteg_dataset_1]
#                      date: 0703mteg5attnostyle           	[default: 0425mteg1att]
#                  deepdown: True
#                descending: False
#              disc_channel: 1
#               disc_kernel: 3
#              disc_retrain: False
#                   dropout: 0.0
#                  enc_loss: False
#                  enc_port: 6
#                     epoch: 871                           	[default: 0]
#                    epochs: 501
#                 ex_critic: True
#                full_style: False
# ...

# %%
for epoch in range(891,881,-10):
    # !python waegan_resnet.py --date '0703mteg5attnostyle' --dataset_name "mteg_dataset_5" --no_relu --no_style --no_noise --attention --style_ratio 0.05 --n_resblk 4 --cpt_interval 10 --batch_size 3 --validate --val_target "user" --epoch $epoch
# Out:
# ----------------- Options ---------------
#                       DDP: False
#                 add_graph: False
#                 attention: True                          	[default: False]
#                batch_size: 3                             	[default: 4]
#                clip_value: 0.01
#               clip_weight: True
#              cpt_interval: 100                           	[default: 10]
#                   dataset: mteg_dataset_5                	[default: mteg_dataset_1]
#                      date: 0703mteg5attnostyle           	[default: 0425mteg1att]
#                  deepdown: True
#                descending: False
#              disc_channel: 1
#               disc_kernel: 3
#              disc_retrain: False
#                   dropout: 0.0
#                  enc_loss: False
#                  enc_port: 6
#                     epoch: 891                           	[default: 0]
#                    epochs: 501
#                 ex_critic: True
# ...

# %%
for epoch in range(921,911,-10):
    # !python waegan_resnet.py --date '0703mteg5attnostyle' --dataset_name "mteg_dataset_5" --no_relu --no_style --no_noise --attention --style_ratio 0.05 --n_resblk 4 --cpt_interval 10 --batch_size 1 --validate --val_target 'test'
# Out:
# ----------------- Options ---------------
#                       DDP: False
#                 add_graph: False
#                 attention: True                          	[default: False]
#                batch_size: 1                             	[default: 4]
#                clip_value: 0.01
#               clip_weight: True
#              cpt_interval: 10
#                   dataset: mteg_dataset_5                	[default: mteg_dataset_1]
#                      date: 0703mteg5attnostyle           	[default: 0425mteg1att]
#                  deepdown: True
#                descending: False
#              disc_channel: 1
#               disc_kernel: 3
#              disc_retrain: False
#                   dropout: 0.0
#                  enc_loss: False
#                  enc_port: 6
#                     epoch: 0
#                    epochs: 501
#                 ex_critic: True
#                full_style: False
#                       gan: True
#                 gp_lambda: 10
# ...

# %%
for epoch in range(601,401,-100):
    # !python waegan_resnet.py --date '0703mteg5attnostylenoclip' --dataset_name "mteg_dataset_5" --no_clip_weight --no_relu --no_style --no_noise --attention --style_ratio 0.05 --n_resblk 4 --cpt_interval 20 --batch_size 3 --validate --epoch $epoch
# Out:
# Namespace(DDP=False, add_graph=False, attention=True, batch_size=3, clip_value=0.01, clip_weight=False, cpt_interval=20, dataset='mteg_dataset_5', date='0703mteg5attnostylenoclip', deepdown=True, descending=False, disc_channel=1, disc_kernel=3, disc_retrain=False, dropout=0.0, enc_loss=False, enc_port=6, epoch=601, epochs=501, ex_critic=True, full_style=False, gan=True, gp_lambda=10, i_normalize=True, img_add=True, img_height=256, img_width=384, k_wass=0.1, lateral=False, lr=0.0002, mse=False, multi_critic=True, n_channel=3, n_critic=3, n_resblk=4, n_z=32, nested=False, noise_in=False, normalize=True, pooled=False, relu_act=False, res_bn=False, res_relu=True, resnet50=False, resnet_torch=True, save=True, sigma=0.1, single8=False, style=False, style_ratio=0.05, swish_act=False, test=False, test_batch_size=10, train=False, train_max=500, wass_metric=True)
# mean mse: 0.05669008361783435
# Sorted!!
# 0	File A:['../../data/mteg_dataset_5/testA/279.png'] 	Test Loss: 5.205633e-01
# ...
