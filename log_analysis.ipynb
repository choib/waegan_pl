# %%
# !python log_parser.py 0520mteg4attvernostylewaegan.log 0520mteg4long.csv
# !sed '301,5981d' 0520mteg4long.csv > 0520mteg4.csv

# %%
import pandas as pd
import numpy as np 
df1 = pd.read_csv('0520mteg4.csv')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.title('Test Loss')
ax= plt.gca()

df1.plot(kind='line',x='Epoch', y='Test Loss', color='red', label='label4',logy = False, ylim=(0,0.15), ax=ax)
# Out:
# <AxesSubplot:title={'center':'Test Loss'}, xlabel='Epoch'>

# %%
plt.title('Generator Loss')
ax= plt.gca()

df1.plot(kind='line',x='Epoch', y='G Loss', color='red', label='label4',logy = True, ylim=(1e-4,0.15), ax=ax)
# Out:
# <AxesSubplot:title={'center':'Generator Loss'}, xlabel='Epoch'>
