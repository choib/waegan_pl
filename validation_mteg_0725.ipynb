# %% [markdown]
# ### Validate train dataset

# %%
epoch = 901
# !python waegan_resnet.py --date '0722mteg5attnostyle' --dataset_name "mteg_dataset_5" --no_noise --attention --style_ratio 0.05 --n_resblk 4 --cpt_interval 10 --batch_size 3 --validate --val_target "train" --epoch $epoch
# Out:
# ----------------- Options ---------------
#                       DDP: False
#                 add_graph: False
#                 attention: True                          	[default: False]
#                batch_size: 3                             	[default: 4]
#                clip_value: 0.01
#               clip_weight: True
#              cpt_interval: 10
#                   dataset: mteg_dataset_5                	[default: mteg_dataset_1]
#                      date: 0722mteg5attnostyle           	[default: 0425mteg1att]
#                descending: False
#              disc_channel: 1
#               disc_kernel: 3
#              disc_retrain: False
#                   dropout: 0.0
#                  enc_port: 6
#                     epoch: 901                           	[default: 0]
#                    epochs: 501
#                 ex_critic: True
#                       gan: True
#                 gp_lambda: 10
#                img_height: 256
# ...

# %% [markdown]
# ### Validate test dataset

# %%
epoch = 901
# !python waegan_resnet.py --date '0722mteg5attnostyle' --dataset_name "mteg_dataset_5" --no_noise --attention --style_ratio 0.05 --n_resblk 4 --cpt_interval 10 --batch_size 3 --validate --val_target "test" --epoch $epoch
# Out:
# ----------------- Options ---------------
#                       DDP: False
#                 add_graph: False
#                 attention: True                          	[default: False]
#                batch_size: 3                             	[default: 4]
#                clip_value: 0.01
#               clip_weight: True
#              cpt_interval: 10
#                   dataset: mteg_dataset_5                	[default: mteg_dataset_1]
#                      date: 0722mteg5attnostyle           	[default: 0425mteg1att]
#                descending: False
#              disc_channel: 1
#               disc_kernel: 3
#              disc_retrain: False
#                   dropout: 0.0
#                  enc_port: 6
#                     epoch: 901                           	[default: 0]
#                    epochs: 501
#                 ex_critic: True
#                       gan: True
#                 gp_lambda: 10
#                img_height: 256
# ...

# %% [markdown]
# ### Validate user dataset:
# * Any dataset can be validated
# * The result is stored at tmp/user_??? directory

# %%
epoch = 901
# !python waegan_resnet.py --date '0722mteg5attnostyle' --dataset_name "mteg_dataset_5" --no_noise --attention --style_ratio 0.05 --n_resblk 4 --cpt_interval 20 --batch_size 3 --validate --val_target "user" --epoch $epoch

# %% [markdown]
# ### Update user dataset:
# * After editing ./tmp/user_result.csv with inspection, the modified result will be applied.
# * The results are stored at *data* directory as *userB*. You may need to clean up *userB* directory before updating.

# %%
epoch = 901
# !python waegan_resnet.py --date '0722mteg5attnostyle' --dataset_name "mteg_dataset_5" --no_noise --attention --style_ratio 0.05 --n_resblk 4 --cpt_interval 20 --batch_size 3 --validate --val_target "update" --epoch $epoch
# Out:
# ----------------- Options ---------------
#                       DDP: False
#                 add_graph: False
#                 attention: True                          	[default: False]
#                batch_size: 3                             	[default: 4]
#                clip_value: 0.01
#               clip_weight: True
#              cpt_interval: 20                            	[default: 10]
#                   dataset: mteg_dataset_5                	[default: mteg_dataset_1]
#                      date: 0722mteg5attnostyle           	[default: 0425mteg1att]
#                descending: False
#              disc_channel: 1
#               disc_kernel: 3
#              disc_retrain: False
#                   dropout: 0.0
#                  enc_port: 6
#                     epoch: 741                           	[default: 0]
#                    epochs: 501
#                 ex_critic: True
#                       gan: True
#                 gp_lambda: 10
# ...
